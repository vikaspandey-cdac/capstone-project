# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %% [markdown]
# ## Extracting features of 2018 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
data = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
data.head(10)
# Out:
#    Opening  Opening.1                    Title  \
# 0  JANUARY          5  Insidious: The Last Key
# 1  JANUARY          5         The Strange Ones
# 2  JANUARY          5                 Stratton
# 3  JANUARY         10            Sweet Country
# 4  JANUARY         12             The Commuter
# 5  JANUARY         12               Proud Mary
# 6  JANUARY         12         Acts of Violence
# 7  JANUARY         12               Freak Show
# 8  JANUARY         12                 Humor Me
# 9  JANUARY         12                  Vazante
#
#                                   Production company  \
# 0  Universal Pictures / Blumhouse Productions / S...
# 1                             Vertical Entertainment
# 2                                  Momentum Pictures
# 3                               Samuel Goldwyn Films
# 4      Lionsgate / StudioCanal / The Picture Company
# 5                                        Screen Gems
# 6                                 Lionsgate Premiere
# 7                                          IFC Films
# 8                    Shout! Factory / Shout! Studios
# 9                                    Music Box Films
#
#                                        Cast and crew  Ref.
# 0  Adam Robitel (director); Leigh Whannell (scree...   [2]
# 1  Lauren Wolkstein (director); Christopher Radcl...   [3]
# 2  Simon West (director); Duncan Falconer, Warren...   [4]
# 3  Warwick Thornton (director); David Tranter, St...   [5]
# 4  Jaume Collet-Serra (director); Byron Willinger...   [6]
# 5  Babak Najafi (director); John S. Newman, Chris...   [7]
# 6  Brett Donowho (director); Nicolas Aaron Mezzan...   [8]
# 7  Trudie Styler (director); Patrick J. Clifton, ...   [9]
# 8  Sam Hoffman (director/screenplay); Jemaine Cle...  [10]
# 9  Daniela Thomas (director/screenplay); Beto Ama...  [11]

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'fc7dd3328b0df9ca81053065a3579964'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
data['genres'] = data['Title'].map(lambda x: get_genre(str(x)))

# %%
data.head()
# Out:
#    Opening  Opening.1                    Title  \
# 0  JANUARY          5  Insidious: The Last Key
# 1  JANUARY          5         The Strange Ones
# 2  JANUARY          5                 Stratton
# 3  JANUARY         10            Sweet Country
# 4  JANUARY         12             The Commuter
#
#                                   Production company  \
# 0  Universal Pictures / Blumhouse Productions / S...
# 1                             Vertical Entertainment
# 2                                  Momentum Pictures
# 3                               Samuel Goldwyn Films
# 4      Lionsgate / StudioCanal / The Picture Company
#
#                                        Cast and crew Ref.  \
# 0  Adam Robitel (director); Leigh Whannell (scree...  [2]
# 1  Lauren Wolkstein (director); Christopher Radcl...  [3]
# 2  Simon West (director); Duncan Falconer, Warren...  [4]
# 3  Warwick Thornton (director); David Tranter, St...  [5]
# 4  Jaume Collet-Serra (director); Byron Willinger...  [6]
#
#                     genres
# 0  Horror Mystery Thriller
# 1           Thriller Drama
# 2          Action Thriller
# 3    Drama History Western
# 4          Action Thriller

# %%
df_2018 = data[['Title','Cast and crew','genres']]

# %%
df_2018.head()
# Out:
#                      Title                                      Cast and crew  \
# 0  Insidious: The Last Key  Adam Robitel (director); Leigh Whannell (scree...
# 1         The Strange Ones  Lauren Wolkstein (director); Christopher Radcl...
# 2                 Stratton  Simon West (director); Duncan Falconer, Warren...
# 3            Sweet Country  Warwick Thornton (director); David Tranter, St...
# 4             The Commuter  Jaume Collet-Serra (director); Byron Willinger...
#
#                     genres
# 0  Horror Mystery Thriller
# 1           Thriller Drama
# 2          Action Thriller
# 3    Drama History Western
# 4          Action Thriller

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
# Out:
# C:\Users\Divyanshu\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# C:\Users\Divyanshu\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\Users\Divyanshu\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2018.head()
# Out:
#                      Title                                      Cast and crew  \
# 0  Insidious: The Last Key  Adam Robitel (director); Leigh Whannell (scree...
# 1         The Strange Ones  Lauren Wolkstein (director); Christopher Radcl...
# 2                 Stratton  Simon West (director); Duncan Falconer, Warren...
# 3            Sweet Country  Warwick Thornton (director); David Tranter, St...
# 4             The Commuter  Jaume Collet-Serra (director); Byron Willinger...
#
#                     genres       director_name    actor_1_name  \
# 0  Horror Mystery Thriller        Adam Robitel       Lin Shaye
# 1           Thriller Drama    Lauren Wolkstein   Alex Pettyfer
# 2          Action Thriller          Simon West  Dominic Cooper
# 3    Drama History Western    Warwick Thornton     Bryan Brown
# 4          Action Thriller  Jaume Collet-Serra     Liam Neeson
#
#              actor_2_name    actor_3_name
# 0           Angus Sampson  Leigh Whannell
# 1  James Freedson-Jackson   Emily Althaus
# 2          Austin Stowell      Gemma Chan
# 3               Sam Neill             NaN
# 4            Vera Farmiga  Patrick Wilson

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df18.head()
# Out:
#         director_name    actor_1_name            actor_2_name    actor_3_name  \
# 0        Adam Robitel       Lin Shaye           Angus Sampson  Leigh Whannell
# 1    Lauren Wolkstein   Alex Pettyfer  James Freedson-Jackson   Emily Althaus
# 2          Simon West  Dominic Cooper          Austin Stowell      Gemma Chan
# 3    Warwick Thornton     Bryan Brown               Sam Neill             NaN
# 4  Jaume Collet-Serra     Liam Neeson            Vera Farmiga  Patrick Wilson
#
#                     genres              movie_title
# 0  Horror Mystery Thriller  Insidious: The Last Key
# 1           Thriller Drama         The Strange Ones
# 2          Action Thriller                 Stratton
# 3    Drama History Western            Sweet Country
# 4          Action Thriller             The Commuter

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']

# %%
new_df18.head()
# Out:
#         director_name    actor_1_name            actor_2_name    actor_3_name  \
# 0        Adam Robitel       Lin Shaye           Angus Sampson  Leigh Whannell
# 1    Lauren Wolkstein   Alex Pettyfer  James Freedson-Jackson   Emily Althaus
# 2          Simon West  Dominic Cooper          Austin Stowell      Gemma Chan
# 3    Warwick Thornton     Bryan Brown               Sam Neill         unknown
# 4  Jaume Collet-Serra     Liam Neeson            Vera Farmiga  Patrick Wilson
#
#                     genres              movie_title  \
# 0  Horror Mystery Thriller  insidious: the last key
# 1           Thriller Drama         the strange ones
# 2          Action Thriller                 stratton
# 3    Drama History Western            sweet country
# 4          Action Thriller             the commuter
#
#                                                 comb
# 0  Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1  Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2  Dominic Cooper Austin Stowell Gemma Chan Simon...
# 3  Bryan Brown Sam Neill unknown Warwick Thornton...
# 4  Liam Neeson Vera Farmiga Patrick Wilson Jaume ...

# %% [markdown]
# ## Extracting features of 2019 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[3]
df2 = pd.read_html(link, header=0)[4]
df3 = pd.read_html(link, header=0)[5]
df4 = pd.read_html(link, header=0)[6]

# %%
data = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
data.head()
# Out:
#    Opening  Opening.1             Title           Production company  \
# 0  JANUARY          4       Escape Room            Columbia Pictures
# 1  JANUARY          4        Rust Creek                    IFC Films
# 2  JANUARY          4  American Hangman  Hangman Justice Productions
# 3  JANUARY         11  A Dog's Way Home            Columbia Pictures
# 4  JANUARY         11        The Upside            STX Entertainment
#
#                                        Cast and crew Ref.
# 0  Adam Robitel (director); Bragi F. Schut, Maria...  [2]
# 1  Jen McGowan (director); Julie Lipson (screenpl...  [3]
# 2  Wilson Coneybeare (director/screenplay); Donal...  [4]
# 3  Charles Martin Smith (director); W. Bruce Came...  [5]
# 4  Neil Burger (director); Jon Hartmere (screenpl...  [6]

# %%
data['genres'] = data['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2019 = data[['Title','Cast and crew','genres']]

# %%
df_2019.head(10)
# Out:
#                            Title  \
# 0                    Escape Room
# 1                     Rust Creek
# 2               American Hangman
# 3               A Dog's Way Home
# 4                     The Upside
# 5                       Replicas
# 6                 After Darkness
# 7                          Glass
# 8                          Close
# 9  The Standoff at Sparrow Creek
#
#                                        Cast and crew  \
# 0  Adam Robitel (director); Bragi F. Schut, Maria...
# 1  Jen McGowan (director); Julie Lipson (screenpl...
# 2  Wilson Coneybeare (director/screenplay); Donal...
# 3  Charles Martin Smith (director); W. Bruce Came...
# 4  Neil Burger (director); Jon Hartmere (screenpl...
# 5  Jeffrey Nachmanoff (director); Chad St. John (...
# 6  Batán Silva (director); Fernando Diez Barroso ...
# 7  M. Night Shyamalan (director/screenplay); Jame...
# 8  Vicky Jewson (director); Vicky Jewson, Rupert ...
# 9  Henry Dunham (director/screenplay); James Badg...
#
#                                      genres
# 0  Thriller Action Mystery Adventure Horror
# 1                            Thriller Drama
# 2                                  Thriller
# 3                    Drama Adventure Family
# 4                              Comedy Drama
# 5                  Thriller Science Fiction
# 6     Drama Family Thriller Science Fiction
# 7            Thriller Drama Science Fiction
# 8                           Action Thriller
# 9                    Drama Thriller Mystery

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\Divyanshu\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# C:\Users\Divyanshu\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\Users\Divyanshu\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']

# %%
new_df19.head(10)
# Out:
#           director_name         actor_1_name        actor_2_name  \
# 0          Adam Robitel       Taylor Russell        Logan Miller
# 1           Jen McGowan    Hermione Corfield         Jay Paulson
# 2     Wilson Coneybeare    Donald Sutherland  Vincent Kartheiser
# 3  Charles Martin Smith  Bryce Dallas Howard  Edward James Olmos
# 4           Neil Burger       Bryan Cranston          Kevin Hart
# 5    Jeffrey Nachmanoff         Keanu Reeves             unknown
# 6           Batán Silva         Natalia Dyer       Kyra Sedgwick
# 7    M. Night Shyamalan         James McAvoy        Bruce Willis
# 8          Vicky Jewson         Noomi Rapace      Sophie Nélisse
# 9          Henry Dunham     James Badge Dale      Brian Geraghty
#
#         actor_3_name                                    genres  \
# 0   Deborah Ann Woll  Thriller Action Mystery Adventure Horror
# 1       Sean O'Bryan                            Thriller Drama
# 2      Oliver Dennis                                  Thriller
# 3    Alexandra Shipp                    Drama Adventure Family
# 4      Nicole Kidman                              Comedy Drama
# 5            unknown                  Thriller Science Fiction
# 6           Tim Daly     Drama Family Thriller Science Fiction
# 7  Samuel L. Jackson            Thriller Drama Science Fiction
# 8       Indira Varma                           Action Thriller
# 9            unknown                    Drama Thriller Mystery
#
#                      movie_title  \
# 0                    escape room
# 1                     rust creek
# 2               american hangman
# 3               a dog's way home
# 4                     the upside
# 5                       replicas
# 6                 after darkness
# 7                          glass
# 8                          close
# 9  the standoff at sparrow creek
#
#                                                 comb
# 0  Taylor Russell Logan Miller Deborah Ann Woll A...
# 1  Hermione Corfield Jay Paulson Sean O'Bryan Jen...
# 2  Donald Sutherland Vincent Kartheiser Oliver De...
# 3  Bryce Dallas Howard Edward James Olmos Alexand...
# 4  Bryan Cranston Kevin Hart Nicole Kidman Neil B...
# 5  Keanu Reeves unknown unknown Jeffrey Nachmanof...
# 6  Natalia Dyer Kyra Sedgwick Tim Daly Batán Silv...
# 7  James McAvoy Bruce Willis Samuel L. Jackson M....
# 8  Noomi Rapace Sophie Nélisse Indira Varma Vicky...
# 9  James Badge Dale Brian Geraghty unknown Henry ...

# %% [markdown]
# ## Extracting features of 2020 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
len(tables)
# Out:
# 4

# %%
type(tables[0])
# Out:
# bs4.element.Tag

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
data = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
data.head(10)
# Out:
#    Opening  Opening.1                               Title  \
# 0  JANUARY          3                          The Grudge
# 1  JANUARY         10                          Underwater
# 2  JANUARY         10                         Like a Boss
# 3  JANUARY         10                       Three Christs
# 4  JANUARY         10                   Inherit the Viper
# 5  JANUARY         10                          The Sonata
# 6  JANUARY         10  The Murder of Nicole Brown Simpson
# 7  JANUARY         17                   Bad Boys for Life
# 8  JANUARY         17                            Dolittle
# 9  JANUARY         17                   A Fall from Grace
#
#                                   Production company  \
# 0  Screen Gems / Stage 6 Films / Ghost House Pict...
# 1  20th Century Fox / TSG Entertainment / Chernin...
# 2                                 Paramount Pictures
# 3                                          IFC Films
# 4     Barry Films / Tycor International Film Company
# 5                                 Screen Media Films
# 6                                Quiver Distribution
# 7  Columbia Pictures / Don Simpson/Jerry Bruckhei...
# 8        Universal Pictures / Perfect World Pictures
# 9                                            Netflix
#
#                                        Cast and crew  Ref.
# 0  Nicolas Pesce (director/screenplay); Andrea Ri...   [2]
# 1  William Eubank (director); Brian Duffield, Ada...   [3]
# 2  Miguel Arteta (director); Sam Pitman, Adam Col...   [4]
# 3  Jon Avnet (director/screenplay); Eric Nazarian...   NaN
# 4  Anthony Jerjen (director); Andrew Crabtree (sc...   [5]
# 5  Andrew Desmond (director/screenplay); Arthur M...   [6]
# 6  Daniel Farrands (director); Michael Arter (scr...   [7]
# 7  Adil El Arbi and Bilall Fallah (directors); Ch...   [8]
# 8  Stephen Gaghan (director/screenplay); Dan Greg...   [9]
# 9  Tyler Perry (director/screenplay); Crystal R. ...  [10]

# %%
df_2020 = data[['Title','Cast and crew']]

# %%
df_2020.head()
# Out:
#                Title                                      Cast and crew
# 0         The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1         Underwater  William Eubank (director); Brian Duffield, Ada...
# 2        Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3      Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4  Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...

# %%
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))
# Out:
# C:\Users\Divyanshu\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2020.head()
# Out:
#                Title                                      Cast and crew  \
# 0         The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1         Underwater  William Eubank (director); Brian Duffield, Ada...
# 2        Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3      Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4  Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
#
#     director_name                                  genres
# 0   Nicolas Pesce                          Horror Mystery
# 1  William Eubank  Action Horror Science Fiction Thriller
# 2   Miguel Arteta                                  Comedy
# 3       Jon Avnet                                   Drama
# 4  Anthony Jerjen                    Drama Thriller Crime

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\Divyanshu\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# C:\Users\Divyanshu\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2020.head()
# Out:
#                Title                                      Cast and crew  \
# 0         The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1         Underwater  William Eubank (director); Brian Duffield, Ada...
# 2        Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3      Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4  Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
#
#     director_name                                  genres        actor_1_name  \
# 0   Nicolas Pesce                          Horror Mystery  Andrea Riseborough
# 1  William Eubank  Action Horror Science Fiction Thriller     Kristen Stewart
# 2   Miguel Arteta                                  Comedy     Tiffany Haddish
# 3       Jon Avnet                                   Drama        Richard Gere
# 4  Anthony Jerjen                    Drama Thriller Crime       Josh Hartnett
#
#         actor_2_name     actor_3_name
# 0      Demián Bichir         John Cho
# 1     Vincent Cassel  Jessica Henwick
# 2         Rose Byrne      Salma Hayek
# 3     Peter Dinklage   Walton Goggins
# 4  Margarita Levieva   Chandler Riggs

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})

# %%
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df20.head(10)
# Out:
#                     director_name        actor_1_name       actor_2_name  \
# 0                   Nicolas Pesce  Andrea Riseborough      Demián Bichir
# 1                  William Eubank     Kristen Stewart     Vincent Cassel
# 2                   Miguel Arteta     Tiffany Haddish         Rose Byrne
# 3                       Jon Avnet        Richard Gere     Peter Dinklage
# 4                  Anthony Jerjen       Josh Hartnett  Margarita Levieva
# 5                  Andrew Desmond       Freya Tingley     Simon Abkarian
# 6                 Daniel Farrands         Mena Suvari         Nick Stahl
# 7  Adil El Arbi and Bilall Fallah          Will Smith    Martin Lawrence
# 8                  Stephen Gaghan   Robert Downey Jr.   Antonio Banderas
# 9                     Tyler Perry      Crystal R. Fox    Phylicia Rashad
#
#       actor_3_name                                  genres  \
# 0         John Cho                          Horror Mystery
# 1  Jessica Henwick  Action Horror Science Fiction Thriller
# 2      Salma Hayek                                  Comedy
# 3   Walton Goggins                                   Drama
# 4   Chandler Riggs                    Drama Thriller Crime
# 5     Rutger Hauer                 Horror Thriller Mystery
# 6    Taryn Manning                    Thriller Drama Crime
# 7  Vanessa Hudgens                   Thriller Action Crime
# 8    Michael Sheen         Comedy Fantasy Adventure Family
# 9      Bresha Webb                                Thriller
#
#                           movie_title
# 0                          The Grudge
# 1                          Underwater
# 2                         Like a Boss
# 3                       Three Christs
# 4                   Inherit the Viper
# 5                          The Sonata
# 6  The Murder of Nicole Brown Simpson
# 7                   Bad Boys for Life
# 8                            Dolittle
# 9                   A Fall from Grace

# %%
new_df20['comb'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['genres']

# %%
new_df20.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      2
# actor_3_name     28
# genres            2
# movie_title       0
# comb             29
# dtype: int64

# %%
new_df20 = new_df20.dropna(how='any')

# %%
new_df20.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df20['movie_title'] = new_df20['movie_title'].str.lower()

# %%
new_df20.head(10)
# Out:
#                     director_name        actor_1_name       actor_2_name  \
# 0                   Nicolas Pesce  Andrea Riseborough      Demián Bichir
# 1                  William Eubank     Kristen Stewart     Vincent Cassel
# 2                   Miguel Arteta     Tiffany Haddish         Rose Byrne
# 3                       Jon Avnet        Richard Gere     Peter Dinklage
# 4                  Anthony Jerjen       Josh Hartnett  Margarita Levieva
# 5                  Andrew Desmond       Freya Tingley     Simon Abkarian
# 6                 Daniel Farrands         Mena Suvari         Nick Stahl
# 7  Adil El Arbi and Bilall Fallah          Will Smith    Martin Lawrence
# 8                  Stephen Gaghan   Robert Downey Jr.   Antonio Banderas
# 9                     Tyler Perry      Crystal R. Fox    Phylicia Rashad
#
#       actor_3_name                                  genres  \
# 0         John Cho                          Horror Mystery
# 1  Jessica Henwick  Action Horror Science Fiction Thriller
# 2      Salma Hayek                                  Comedy
# 3   Walton Goggins                                   Drama
# 4   Chandler Riggs                    Drama Thriller Crime
# 5     Rutger Hauer                 Horror Thriller Mystery
# 6    Taryn Manning                    Thriller Drama Crime
# 7  Vanessa Hudgens                   Thriller Action Crime
# 8    Michael Sheen         Comedy Fantasy Adventure Family
# 9      Bresha Webb                                Thriller
#
#                           movie_title  \
# 0                          the grudge
# 1                          underwater
# 2                         like a boss
# 3                       three christs
# 4                   inherit the viper
# 5                          the sonata
# 6  the murder of nicole brown simpson
# 7                   bad boys for life
# 8                            dolittle
# 9                   a fall from grace
#
#                                                 comb
# 0  Andrea Riseborough Demián Bichir John Cho Nico...
# 1  Kristen Stewart Vincent Cassel Jessica Henwick...
# 2  Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3  Richard Gere Peter Dinklage Walton Goggins Jon...
# 4  Josh Hartnett Margarita Levieva Chandler Riggs...
# 5  Freya Tingley Simon Abkarian Rutger Hauer Andr...
# 6  Mena Suvari Nick Stahl Taryn Manning Daniel Fa...
# 7  Will Smith Martin Lawrence Vanessa Hudgens Adi...
# 8  Robert Downey Jr. Antonio Banderas Michael She...
# 9  Crystal R. Fox Phylicia Rashad Bresha Webb Tyl...

# %% [markdown]
# ### Combining dataframes:

# %%
mid_df1 = new_df18.append(new_df19,ignore_index=True)

# %%
mid_df1
# Out:
#              director_name       actor_1_name            actor_2_name  \
# 0             Adam Robitel          Lin Shaye           Angus Sampson
# 1         Lauren Wolkstein      Alex Pettyfer  James Freedson-Jackson
# 2               Simon West     Dominic Cooper          Austin Stowell
# 3         Warwick Thornton        Bryan Brown               Sam Neill
# 4       Jaume Collet-Serra        Liam Neeson            Vera Farmiga
# ..                     ...                ...                     ...
# 505           Greta Gerwig      Saoirse Ronan             Emma Watson
# 506             Sam Mendes      George MacKay    Dean-Charles Chapman
# 507  Destin Daniel Cretton  Michael B. Jordan              Jamie Foxx
# 508        Chinonye Chukwu      Alfre Woodard          Wendell Pierce
# 509           Waymon Boone        Mena Suvari            Kevin Pollak
#
#        actor_3_name                   genres              movie_title  \
# 0    Leigh Whannell  Horror Mystery Thriller  insidious: the last key
# 1     Emily Althaus           Thriller Drama         the strange ones
# 2        Gemma Chan          Action Thriller                 stratton
# 3           unknown    Drama History Western            sweet country
# 4    Patrick Wilson          Action Thriller             the commuter
# ..              ...                      ...                      ...
# 505   Florence Pugh            Drama Romance             little women
# 506     Mark Strong         War Drama Action                     1917
# 507     Brie Larson                    Drama               just mercy
# 508     Aldis Hodge                    Drama                 clemency
# 509         unknown          Horror Thriller               apparition
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2    Dominic Cooper Austin Stowell Gemma Chan Simon...
# 3    Bryan Brown Sam Neill unknown Warwick Thornton...
# 4    Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# ..                                                 ...
# 505  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 506  George MacKay Dean-Charles Chapman Mark Strong...
# 507  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 508  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
# 509  Mena Suvari Kevin Pollak unknown Waymon Boone ...
#
# [510 rows x 7 columns]

# %%
mid_df = mid_df1.append(new_df20,ignore_index=True)

# %%
mid_df
# Out:
#            director_name       actor_1_name            actor_2_name  \
# 0           Adam Robitel          Lin Shaye           Angus Sampson
# 1       Lauren Wolkstein      Alex Pettyfer  James Freedson-Jackson
# 2             Simon West     Dominic Cooper          Austin Stowell
# 3       Warwick Thornton        Bryan Brown               Sam Neill
# 4     Jaume Collet-Serra        Liam Neeson            Vera Farmiga
# ..                   ...                ...                     ...
# 736  Paul W. S. Anderson     Milla Jovovich                Tony Jaa
# 737          Regina King  Kingsley Ben-Adir               Eli Goree
# 738      Emerald Fennell     Carey Mulligan              Bo Burnham
# 739          Eugene Ashe     Tessa Thompson         Nnamdi Asomugha
# 740     Kornél Mundruczó      Vanessa Kirby            Shia LaBeouf
#
#             actor_3_name                    genres              movie_title  \
# 0         Leigh Whannell   Horror Mystery Thriller  insidious: the last key
# 1          Emily Althaus            Thriller Drama         the strange ones
# 2             Gemma Chan           Action Thriller                 stratton
# 3                unknown     Drama History Western            sweet country
# 4         Patrick Wilson           Action Thriller             the commuter
# ..                   ...                       ...                      ...
# 736    Tip "T.I." Harris  Fantasy Action Adventure           monster hunter
# 737          Aldis Hodge                     Drama       one night in miami
# 738          Alison Brie      Thriller Crime Drama    promising young woman
# 739  Ryan Michelle Bathe                     Drama            sylvie's love
# 740         Molly Parker                     Drama        pieces of a woman
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2    Dominic Cooper Austin Stowell Gemma Chan Simon...
# 3    Bryan Brown Sam Neill unknown Warwick Thornton...
# 4    Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# ..                                                 ...
# 736  Milla Jovovich Tony Jaa Tip "T.I." Harris Paul...
# 737  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 738  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 739  Tessa Thompson Nnamdi Asomugha Ryan Michelle B...
# 740  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [741 rows x 7 columns]

# %%
old_df = pd.read_csv("datasets/new_data.csv")

# %%
old_df.head()
# Out:
#        director_name     actor_1_name      actor_2_name          actor_3_name  \
# 0      James Cameron      CCH Pounder  Joel David Moore             Wes Studi
# 1     Gore Verbinski      Johnny Depp     Orlando Bloom        Jack Davenport
# 2         Sam Mendes  Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3  Christopher Nolan        Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4        Doug Walker      Doug Walker        Rob Walker               unknown
#
#                             genres  \
# 0  Action Adventure Fantasy Sci-Fi
# 1         Action Adventure Fantasy
# 2        Action Adventure Thriller
# 3                  Action Thriller
# 4                      Documentary
#
#                                          movie_title  \
# 0                                             avatar
# 1           pirates of the caribbean: at world's end
# 2                                            spectre
# 3                              the dark knight rises
# 4  star wars: episode vii - the force awakens    ...
#
#                                                 comb
# 0  CCH Pounder Joel David Moore Wes Studi James C...
# 1  Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2  Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3  Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4  Doug Walker Rob Walker unknown Doug Walker Doc...

# %%
final_df = old_df.append(mid_df,ignore_index=True)

# %%
final_df
# Out:
#             director_name       actor_1_name      actor_2_name  \
# 0           James Cameron        CCH Pounder  Joel David Moore
# 1          Gore Verbinski        Johnny Depp     Orlando Bloom
# 2              Sam Mendes    Christoph Waltz      Rory Kinnear
# 3       Christopher Nolan          Tom Hardy    Christian Bale
# 4             Doug Walker        Doug Walker        Rob Walker
# ...                   ...                ...               ...
# 6100  Paul W. S. Anderson     Milla Jovovich          Tony Jaa
# 6101          Regina King  Kingsley Ben-Adir         Eli Goree
# 6102      Emerald Fennell     Carey Mulligan        Bo Burnham
# 6103          Eugene Ashe     Tessa Thompson   Nnamdi Asomugha
# 6104     Kornél Mundruczó      Vanessa Kirby      Shia LaBeouf
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 6100     Tip "T.I." Harris         Fantasy Action Adventure
# 6101           Aldis Hodge                            Drama
# 6102           Alison Brie             Thriller Crime Drama
# 6103   Ryan Michelle Bathe                            Drama
# 6104          Molly Parker                            Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6100                                     monster hunter
# 6101                                 one night in miami
# 6102                              promising young woman
# 6103                                      sylvie's love
# 6104                                  pieces of a woman
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 6100  Milla Jovovich Tony Jaa Tip "T.I." Harris Paul...
# 6101  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 6102  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 6103  Tessa Thompson Nnamdi Asomugha Ryan Michelle B...
# 6104  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [6105 rows x 7 columns]

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           4
# movie_title      0
# comb             4
# dtype: int64

# %%
final_df = final_df.dropna(how='any')

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df.to_csv("datasets/final_data.csv")
